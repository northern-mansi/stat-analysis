# %%
import pandas as pd

# %%
merged_df = pd.read_csv("./clean/merged_data_03_05.csv")
merged_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 0     (Moꞩ tuw) mȯꞩ nē jäɣpı̮ɣēntəl ɔ̄leı̮ɣ     0    A    AV  NoPtcl  npst
# 1                                χɔsa ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 2                               wat'i ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 3         mχ urən pal sāw sɔ̇mjaχ taɣintapti      1    A   APV  NoPtcl  npst
# 4          wȯrəŋ pal sāw sɔ̇mjaχ taɣ͕əntapti     1    A    PV  NoPtcl  npst
# ...                                        ...   ...  ...   ...     ...   ...
# 4473                          nul ta pāltwes      X    P     V      ta   pst
# 4474          ker sol'aɣenəl  χɔ̄t manumtawes      X    P     V  NoPtcl   pst
# 4475                         ul'an ta pāltwes     X    P     V      ta   pst
# 4476             ta χum uı̯anetəl ań ta ɔ̄li,      0    A    AV      ta  npst
# 4477                               ań ta ꞩuńi.     0    A     V      ta  npst
#
# ...

# %%
merged_df["Form"] = merged_df["Form"].apply(lambda col: col.replace("INF-", ""))

# %%
a_only_df = merged_df[~merged_df["A-rform"].isna() & merged_df["O-rform"].isna()]
a_only_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 0     (Moꞩ tuw) mȯꞩ nē jäɣpı̮ɣēntəl ɔ̄leı̮ɣ     0    A    AV  NoPtcl  npst
# 1                                χɔsa ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 2                               wat'i ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 5                        ɔ̄limētēn lāwi: -      0    A     V  NoPtcl  npst
# 7                                   Ta minas,      0    A     V      ta   pst
# ...                                        ...   ...  ...   ...     ...   ...
# 4468                   KSU. nupəl sau̯ ꞩarɣi.      0    A     V  NoPtcl  npst
# 4469                   tau̯ nupəle sime ꞩārɣi     0    A    AV  NoPtcl  npst
# 4470                  āpꞩite nupəl moꞩa ꞩarɣi     0    A     V  NoPtcl  npst
# 4476             ta χum uı̯anetəl ań ta ɔ̄li,      0    A    AV      ta  npst
# 4477                               ań ta ꞩuńi.     0    A     V      ta  npst
#
# ...

# %%
o_only_df = merged_df[merged_df["A-rform"].isna() & ~merged_df["O-rform"].isna()]
o_only_df
# Out:
#                                               Sentence Trans Form W-ord  \
# 51                  ań nē sis kȯt'il't tāra pēlwes     X    P    PV
# 66          Am tuw jālum l'ɔ̄ŋχu̮m lap-wos wɔ̄tastawe     X    P    PV
# 76     ērı̮ɣ tȯtne χum mȯjt tȯtne χum jānı̮ɣwes,      0    P    AV
# 92                                 χȯttal wɔ̄tastawes     0    P     V
# 152                             ēlmχɔlɒs ta sāwatawe     X    P    PV
# ...                                                ...   ...  ...   ...
# 4471                                    ul'a paltwes,      X    P    PV
# 4472                              ul'an ta woꞩkasawes.     X    P     V
# 4473                                  nul ta pāltwes      X    P     V
# 4474                  ker sol'aɣenəl  χɔ̄t manumtawes      X    P     V
# 4475                                 ul'an ta pāltwes     X    P     V
#
#         Ptcl   Tns Mood  SenT   Pfv A-anim  ... A-uniq A-fam O-anim O-numb  \
# ...

# %%
ao_df = merged_df[~merged_df["A-rform"].isna() & ~merged_df["O-rform"].isna()]
ao_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 3         mχ urən pal sāw sɔ̇mjaχ taɣintapti      1    A   APV  NoPtcl  npst
# 4          wȯrəŋ pal sāw sɔ̇mjaχ taɣ͕əntapti     1    A    PV  NoPtcl  npst
# 11          ūsm ɔ̄tər ɔ̄jka ɔńꞩi χūru̮m āɣi     1    A   AVP  NoPtcl  npst
# 12                       χajtalaste mań āɣi:      1   AP    VP  NoPtcl   pst
# 14                               pȯ̭r tēɣt,      1    A    PV  NoPtcl  npst
# ...                                        ...   ...  ...   ...     ...   ...
# 4430  ɔs ɔ̄χsɒr ɔ̄ı̯ka tur χɔ̄sit ta pēlwès,      X    P     V      ta   pst
# 4437         χotum lawi ɔs nɔŋχ ı̯altupte:len      1   AP     V  NoPtcl  npst
# 4442      anum χāpɣa puŋna sup tı̮ɣ totelen.      1   AP    PV  NoPtcl  npst
# 4453                  koꞩaı̯ ɔs ı̯altŭptawes.     X    P    AV  NoPtcl   pst
# 4458                    ań āpꞩitēn wȯı̯wès      1    P    AV  NoPtcl   pst
#
# ...

# %%
imp_df = merged_df[merged_df["A-rform"].isna() & merged_df["O-rform"].isna()]
imp_df
# Out:
#                                    Sentence Trans Form W-ord    Ptcl   Tns  \
# 6     Nēɣ͕əŋ mā, tumiŋ mā kinsuŋkwe ēri     0    A    AV  NoPtcl  npst
# 20                       Juw-minu̮ŋkwe ēri     0    A    AV  NoPtcl  npst
# 22              - Minuŋkwe naŋən χuńt rɔu̯s     0    A    AV  NoPtcl   pst
# 32                  Akw χɔ̄tɒlı̮ɣ jēmtəs,      0    A     V  NoPtcl   pst
# 140                          tuijiɣ jēmtəs     0    A     V  NoPtcl   pst
# ...                                     ...   ...  ...   ...     ...   ...
# 4001                     at rɔ̄u̯i, lāwi,      0    A     V  NoPtcl  npst
# 4120                 χolitanı̮ɣ ı̯ēmtəs,       0    A     V  NoPtcl   pst
# 4163                  χolitanı̮ɣ ı̯ēmtəs,      0    A     V  NoPtcl   pst
# 4224                 nemat piꞩum at ārtmi.     0    A     V  NoPtcl  npst
# 4337                    kinsuŋkwe ta patsət     0    A     V      ta   pst
#
# ...

# %%
a_only_df = a_only_df.drop(columns=[col for col in a_only_df.columns if col.startswith("O-")])
a_only_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 0     (Moꞩ tuw) mȯꞩ nē jäɣpı̮ɣēntəl ɔ̄leı̮ɣ     0    A    AV  NoPtcl  npst
# 1                                χɔsa ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 2                               wat'i ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 5                        ɔ̄limētēn lāwi: -      0    A     V  NoPtcl  npst
# 7                                   Ta minas,      0    A     V      ta   pst
# ...                                        ...   ...  ...   ...     ...   ...
# 4468                   KSU. nupəl sau̯ ꞩarɣi.      0    A     V  NoPtcl  npst
# 4469                   tau̯ nupəle sime ꞩārɣi     0    A    AV  NoPtcl  npst
# 4470                  āpꞩite nupəl moꞩa ꞩarɣi     0    A     V  NoPtcl  npst
# 4476             ta χum uı̯anetəl ań ta ɔ̄li,      0    A    AV      ta  npst
# 4477                               ań ta ꞩuńi.     0    A     V      ta  npst
#
# ...

# %%
a_only_df = a_only_df.dropna()
a_only_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 0     (Moꞩ tuw) mȯꞩ nē jäɣpı̮ɣēntəl ɔ̄leı̮ɣ     0    A    AV  NoPtcl  npst
# 1                                χɔsa ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 2                               wat'i ɔ̄lsı̮ɣ      0    A     V  NoPtcl   pst
# 5                        ɔ̄limētēn lāwi: -      0    A     V  NoPtcl  npst
# 7                                   Ta minas,      0    A     V      ta   pst
# ...                                        ...   ...  ...   ...     ...   ...
# 4468                   KSU. nupəl sau̯ ꞩarɣi.      0    A     V  NoPtcl  npst
# 4469                   tau̯ nupəle sime ꞩārɣi     0    A    AV  NoPtcl  npst
# 4470                  āpꞩite nupəl moꞩa ꞩarɣi     0    A     V  NoPtcl  npst
# 4476             ta χum uı̯anetəl ań ta ɔ̄li,      0    A    AV      ta  npst
# 4477                               ań ta ꞩuńi.     0    A     V      ta  npst
#
# ...

# %%
o_only_df = o_only_df.drop(columns=[col for col in o_only_df.columns if col.startswith("A-")])
o_only_df
# Out:
#                                               Sentence Trans Form W-ord  \
# 51                  ań nē sis kȯt'il't tāra pēlwes     X    P    PV
# 66          Am tuw jālum l'ɔ̄ŋχu̮m lap-wos wɔ̄tastawe     X    P    PV
# 76     ērı̮ɣ tȯtne χum mȯjt tȯtne χum jānı̮ɣwes,      0    P    AV
# 92                                 χȯttal wɔ̄tastawes     0    P     V
# 152                             ēlmχɔlɒs ta sāwatawe     X    P    PV
# ...                                                ...   ...  ...   ...
# 4471                                    ul'a paltwes,      X    P    PV
# 4472                              ul'an ta woꞩkasawes.     X    P     V
# 4473                                  nul ta pāltwes      X    P     V
# 4474                  ker sol'aɣenəl  χɔ̄t manumtawes      X    P     V
# 4475                                 ul'an ta pāltwes     X    P     V
#
#         Ptcl   Tns Mood  SenT   Pfv O-anim O-numb O-rform O-rstat   O-sp  \
# ...

# %%
ao_df[ao_df.isna().any(axis=1)]
# Out:
#                                           Sentence Trans Form W-ord    Ptcl  \
# 53                         Ań am manər wāreɣu̮m,      1    A   APV  NoPtcl
# 55                              Anꞩw salaste xɔt,      1   AP     V  NoPtcl
# 56                   tau̯ ȱ̭lamane χɔt - aŋχw ɔs     1    A    PV  NoPtcl
# 57                   Mańe ȱ̭lamt nɔŋχ - wasane,      1   AP    PV  NoPtcl
# 149                        ɔ̄limēte unttəs ńawram     1    A    VP  NoPtcl
# 154              ēlmχȯlɒs jaɣāɣin ul ȯpētiten     1    A    PV  NoPtcl
# 183    Man taχ NƆ̄Ɔ̄ āmpēn wɔ̄ŋχa āwi χȯrmtawe     1    P   APV  NoPtcl
# 279                       mēn mēn ul nȯu̯χaten,     1    A    PV  NoPtcl
# 322                           takwa ȱsma ꞩɔ̄piti     1    A    PV  NoPtcl
# 386                            kos āmpən tēwet,      1    P    AV  NoPtcl
# 387                           kos matarən tēwet,      1    P    AV  NoPtcl
# ...

# %%
ao_df.at[4363, "A-rstat"] = "top"
ao_df.loc[4363]
# Out:
# Sentence                                  nɔ̄ŋχ ti χartsanəl
# Trans                                                       1
# Form                                                       AP
# W-ord                                                       V
# Ptcl                                                       ti
# Tns                                                       pst
# Mood                                                      ind
# SenT                                                     none
# Pfv                                                       pfv
# A-anim                                                      A
# A-numb                                                     pl
# A-rform                                                  zero
# A-rstat                                                   top
# A-sp                                                       sp
# A-uniq                                                   uniq
# ...

# %%
ao_df[ao_df.isna().any(axis=1)]
# Out:
#                                           Sentence Trans Form W-ord    Ptcl  \
# 53                         Ań am manər wāreɣu̮m,      1    A   APV  NoPtcl
# 55                              Anꞩw salaste xɔt,      1   AP     V  NoPtcl
# 56                   tau̯ ȱ̭lamane χɔt - aŋχw ɔs     1    A    PV  NoPtcl
# 57                   Mańe ȱ̭lamt nɔŋχ - wasane,      1   AP    PV  NoPtcl
# 149                        ɔ̄limēte unttəs ńawram     1    A    VP  NoPtcl
# 154              ēlmχȯlɒs jaɣāɣin ul ȯpētiten     1    A    PV  NoPtcl
# 183    Man taχ NƆ̄Ɔ̄ āmpēn wɔ̄ŋχa āwi χȯrmtawe     1    P   APV  NoPtcl
# 279                       mēn mēn ul nȯu̯χaten,     1    A    PV  NoPtcl
# 322                           takwa ȱsma ꞩɔ̄piti     1    A    PV  NoPtcl
# 386                            kos āmpən tēwet,      1    P    AV  NoPtcl
# 387                           kos matarən tēwet,      1    P    AV  NoPtcl
# ...

# %%
values = {
    53: {
        "O-rstat": "undef",
        "O-sp": "nonsp",
        "O-uniq": "nuniq",
        "O-fam": "nfam"
    },
    55: {
        "O-rstat": "act",
        "O-sp": "sp",
        "O-uniq": "uniq",
        "O-fam": "weak"
    },
    56: {
        "O-rstat": "ref",
        "O-sp": "sp",
        "O-uniq": "uniq",
        "O-fam": "strg"
    },
    57: {
        "O-rstat": "act",
        "O-sp": "sp",
        "O-uniq": "uniq",
        "O-fam": "strg"
    },
    149: {
        "O-rstat": "typid",
        "O-sp": "sp",
        "O-uniq": "nuniq",
        "O-fam": "weak"
    },
    154: {
        "O-rstat": "uniq",
        "O-sp": "sp",
        "O-uniq": "uniq",
        "O-fam": "strg"
    },
    279: {
        "O-rstat": "act",
        "O-sp": "sp",
        "O-uniq": "uniq",
        "O-fam": "strg"
    },
    183: {
        "A-rstat": "act",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    322: {
        "A-rstat": "act",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    892: {
        "A-rstat": "act",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    2481: {
        "A-rstat": "act",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    917: {
        "A-rstat": "fam",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    2409: {
        "A-rstat": "fam",
        "A-sp": "sp",
        "A-uniq": "uniq",
        "A-fam": "strg"
    },
    386: {
        "A-rstat": "typid",
        "A-sp": "nonsp",
        "A-uniq": "nuniq",
        "A-fam": "nfam"
    },
    387: {
        "A-rstat": "typid",
        "A-sp": "nonsp",
        "A-uniq": "nuniq",
        "A-fam": "nfam"
    },
}
drop_rows = [922, 2936, 3465]

# %%
for index in values:
    for (k, v) in values[index].items():
        ao_df.at[index, k] = v

# %%
ao_df[ao_df.isna().any(axis=1)]
# Out:
#                                  Sentence Trans Form W-ord    Ptcl   Tns  \
# 922    puŋkum man̩ si̊p tan lomten úrāve     1    P   PAV  NoPtcl  npst
# 2936                        pusьn ratmane     1   AP    PV  NoPtcl   pst
# 3465                    sar manər wareı̮ɣ     1    A    PV  NoPtcl  npst
#
#       Mood  SenT   Pfv A-anim  ... A-uniq A-fam O-anim O-numb O-rform O-rstat  \
# 922    ind  none  npfv      I  ...    NaN   NaN      I     sg  possnp    uniq
# 2936  evid  none   pfv      H  ...    NaN   NaN      I     pl   npron     ref
# 3465   ind  none  npfv      H  ...   uniq  strg      U   abst   npron     NaN
#
#      O-sp O-uniq O-fam                                               File
# 922    sp   uniq  weak  NM_Sosva_Chernetsov_42_PTM_final.xlsx - Sheet1...
# 2936   sp   uniq  strg  NM_Sosva_Chernetsov_42_AOMS_final.xlsx - Sheet...
# 3465  NaN    NaN   NaN  NM_UpperLozva_Chernetsov_51_ANOA_final.xlsx - ...
#
# [3 rows x 24 columns]

# %%
for index in drop_rows:
    ao_df = ao_df.drop(index = index)

# %%
ao_df[ao_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Sentence, Trans, Form, W-ord, Ptcl, Tns, Mood, SenT, Pfv, A-anim, A-numb, A-rform, A-rstat, A-sp, A-uniq, A-fam, O-anim, O-numb, O-rform, O-rstat, O-sp, O-uniq, O-fam, File]
# Index: []
#
# [0 rows x 24 columns]

# %%
ao_df
# Out:
#                                       Sentence Trans Form W-ord    Ptcl   Tns  \
# 3         mχ urən pal sāw sɔ̇mjaχ taɣintapti      1    A   APV  NoPtcl  npst
# 4          wȯrəŋ pal sāw sɔ̇mjaχ taɣ͕əntapti     1    A    PV  NoPtcl  npst
# 11          ūsm ɔ̄tər ɔ̄jka ɔńꞩi χūru̮m āɣi     1    A   AVP  NoPtcl  npst
# 12                       χajtalaste mań āɣi:      1   AP    VP  NoPtcl   pst
# 14                               pȯ̭r tēɣt,      1    A    PV  NoPtcl  npst
# ...                                        ...   ...  ...   ...     ...   ...
# 4430  ɔs ɔ̄χsɒr ɔ̄ı̯ka tur χɔ̄sit ta pēlwès,      X    P     V      ta   pst
# 4437         χotum lawi ɔs nɔŋχ ı̯altupte:len      1   AP     V  NoPtcl  npst
# 4442      anum χāpɣa puŋna sup tı̮ɣ totelen.      1   AP    PV  NoPtcl  npst
# 4453                  koꞩaı̯ ɔs ı̯altŭptawes.     X    P    AV  NoPtcl   pst
# 4458                    ań āpꞩitēn wȯı̯wès      1    P    AV  NoPtcl   pst
#
# ...

# %%
ao_df[(ao_df["A-rform"] == "zero") & (ao_df["O-rform"] == "zero") & (ao_df["Form"] != "AP")]
# Out:
#                                  Sentence Trans Form W-ord    Ptcl   Tns Mood  \
# 1289     Artalas nila kol lapne janit mā     1    A    VP  NoPtcl   pst  ind
# 4134                    ɔ̄s ti lakwsa:we.     X    P     V      ti  npst  ind
# 4315  ı̯aɣaɣitèn ta totwès kuꞩńèꞩ pālt.      1    P    AV      ta   pst  ind
# 4371   tɔ̄rewn ꞩaχnil kos ı̯unı̮ɣtalàwe,      1    P     V  NoPtcl  npst  ind
# 4387      manı̮ɣtaŋkwe ta tultı̮ɣpuχtasət     1    A     V      ta   pst  ind
#
#       SenT  Pfv A-anim  ... A-uniq A-fam O-anim O-numb O-rform O-rstat O-sp  \
# 1289  none  pfv      H  ...   uniq  strg      I     sg    zero     ref   sp
# 4134  none  pfv      A  ...   uniq  strg      A     sg    zero     act   sp
# 4315  none  pfv      H  ...   uniq  strg      H     sg    zero     top   sp
# 4371  none  pfv      A  ...   uniq  weak      I     sg    zero     top   sp
# 4387  none  pfv      A  ...   uniq  strg      I     sg    zero     top   sp
#
# ...

# %%
for idx in (4134, 4387):
    ao_df = ao_df.drop(index = idx)

# %%
ao_df[(ao_df["A-rform"] == "zero") & (ao_df["O-rform"] == "zero") & (ao_df["Form"] != "AP")]
# Out:
#                                  Sentence Trans Form W-ord    Ptcl   Tns Mood  \
# 1289     Artalas nila kol lapne janit mā     1    A    VP  NoPtcl   pst  ind
# 4315  ı̯aɣaɣitèn ta totwès kuꞩńèꞩ pālt.      1    P    AV      ta   pst  ind
# 4371   tɔ̄rewn ꞩaχnil kos ı̯unı̮ɣtalàwe,      1    P     V  NoPtcl  npst  ind
#
#       SenT  Pfv A-anim  ... A-uniq A-fam O-anim O-numb O-rform O-rstat O-sp  \
# 1289  none  pfv      H  ...   uniq  strg      I     sg    zero     ref   sp
# 4315  none  pfv      H  ...   uniq  strg      H     sg    zero     top   sp
# 4371  none  pfv      A  ...   uniq  weak      I     sg    zero     top   sp
#
#      O-uniq O-fam                                               File
# 1289  nuniq  nfam  NM_Sosva_Chernetsov_42_PTM_final.xlsx - Sheet1...
# 4315   uniq  strg  NM_UpperLozva_Chernetsov_50_1_final.xlsx - Ful...
# 4371   uniq  strg  NM_UpperLozva_Chernetsov_50_1_final.xlsx - Ful...
#
# [3 rows x 24 columns]

# %%
ao_df.at[1289, "O-rform"] = "barenp"
ao_df.at[4315, "A-rform"] = "barenp"
ao_df.at[4371, "A-rform"] = "barenp"

# %%
ao_df[(ao_df["A-rform"] == "zero") & (ao_df["O-rform"] == "zero") & (ao_df["Form"] != "AP")]
# Out:
# Empty DataFrame
# Columns: [Sentence, Trans, Form, W-ord, Ptcl, Tns, Mood, SenT, Pfv, A-anim, A-numb, A-rform, A-rstat, A-sp, A-uniq, A-fam, O-anim, O-numb, O-rform, O-rstat, O-sp, O-uniq, O-fam, File]
# Index: []
#
# [0 rows x 24 columns]

# %%
a_only_df = a_only_df.drop(columns=["File"])
o_only_df = o_only_df.drop(columns=["File"])
ao_df = ao_df.drop(columns=["File"])
imp_df = imp_df.drop(columns=["File"])

# %%
a_only_df.to_csv("./clean/A_only.csv", index=False)
o_only_df.to_csv("./clean/O_only.csv", index=False)
ao_df.to_csv("./clean/AO.csv", index=False)
imp_df.to_csv("./clean/Imp.csv", index=False)
